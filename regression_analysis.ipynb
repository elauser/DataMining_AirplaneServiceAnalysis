# %% [markdown]
# ## Summary of Dataset

# %%
import pandas as pd

df = pd.read_csv('final_data.csv')
stats = df.describe().T
stats = stats[['mean', 'std']]
stats
# Out:
#                                    mean       std
# overall_rating                 6.144748  3.048280
# seat_comfort_rating            3.127476  1.203413
# cabin_staff_rating             3.492125  1.366735
# food_beverages_rating          3.037443  1.206316
# inflight_entertainment_rating  2.530486  1.243964
# value_money_rating             3.257223  1.452115
# recommended                    0.533820  0.498861
# fear                           0.096558  0.006249
# anger                          0.093430  0.006339
# anticip                        0.095945  0.006342
# trust                          0.111294  0.009546
# surprise                       0.092849  0.005942
# positive                       0.115593  0.009062
# negative                       0.107264  0.007335
# sadness                        0.095502  0.006302
# disgust                        0.093416  0.006232
# joy                            0.098149  0.007022
# overall_sentiment              0.036926  0.051568
# ...

# %% [markdown]
# ## Multiple Linear Regression Model1

# %%
from sklearn import linear_model
import statsmodels.api as sm

y_rating = df.overall_rating
y_recommended = df.recommended

x = df.drop(columns=['overall_rating', 'recommended', 'cabin_flown', 'positive', 'negative'])
x_model1 = x.iloc[:,:5]
x_model2 = x.iloc[:,:14]
x_model3 = x

# %% [markdown]
# ### Model1

# %%
est = sm.OLS(y_rating, x_model1)
est2 = est.fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:         overall_rating   R-squared (uncentered):                   0.921
# Model:                            OLS   Adj. R-squared (uncentered):              0.921
# Method:                 Least Squares   F-statistic:                          9.605e+04
# Date:                Sun, 11 Oct 2020   Prob (F-statistic):                        0.00
# Time:                        15:45:09   Log-Likelihood:                         -86003.
# No. Observations:               41396   AIC:                                  1.720e+05
# Df Residuals:                   41391   BIC:                                  1.721e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Model2

# %%
est = sm.OLS(y_rating, x_model2)
est2 = est.fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:         overall_rating   R-squared (uncentered):                   0.922
# Model:                            OLS   Adj. R-squared (uncentered):              0.922
# Method:                 Least Squares   F-statistic:                          3.503e+04
# Date:                Sun, 11 Oct 2020   Prob (F-statistic):                        0.00
# Time:                        15:45:04   Log-Likelihood:                         -85600.
# No. Observations:               41396   AIC:                                  1.712e+05
# Df Residuals:                   41382   BIC:                                  1.713e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# ### Model3

# %%
est = sm.OLS(y_rating, x_model3)
est2 = est.fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:         overall_rating   R-squared (uncentered):                   0.922
# Model:                            OLS   Adj. R-squared (uncentered):              0.922
# Method:                 Least Squares   F-statistic:                          2.454e+04
# Date:                Sun, 11 Oct 2020   Prob (F-statistic):                        0.00
# Time:                        15:44:49   Log-Likelihood:                         -85578.
# No. Observations:               41396   AIC:                                  1.712e+05
# Df Residuals:                   41376   BIC:                                  1.714e+05
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# # Logistical Regression Recommendation Behaviour

# %% [markdown]
# ## Model1

# %%
est = sm.Logit(y_recommended, x_model1)
est2 = est.fit()
est2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.593769
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            recommended   No. Observations:                41396
# Model:                          Logit   Df Residuals:                    41391
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 11 Oct 2020   Pseudo R-squ.:                  0.1405
# Time:                        16:13:32   Log-Likelihood:                -24580.
# converged:                       True   LL-Null:                       -28599.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Model2

# %%
est = sm.Logit(y_recommended, x_model2)
est2 = est.fit()
est2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.255490
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            recommended   No. Observations:                41396
# Model:                          Logit   Df Residuals:                    41382
# Method:                           MLE   Df Model:                           13
# Date:                Sun, 11 Oct 2020   Pseudo R-squ.:                  0.6302
# Time:                        16:15:24   Log-Likelihood:                -10576.
# converged:                       True   LL-Null:                       -28599.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Model3

# %%
est = sm.Logit(y_recommended, x_model3)
est2 = est.fit()
est2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.255094
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            recommended   No. Observations:                41396
# Model:                          Logit   Df Residuals:                    41376
# Method:                           MLE   Df Model:                           19
# Date:                Sun, 11 Oct 2020   Pseudo R-squ.:                  0.6308
# Time:                        16:15:30   Log-Likelihood:                -10560.
# converged:                       True   LL-Null:                       -28599.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...
